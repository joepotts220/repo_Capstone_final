# %% [markdown]
# # capstone_final.ipynb

# %% [markdown]
# #### Import the needed Python libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Read the initial CSV data file into Pandas.

# %%
df_orig = pd.read_csv("cbecs2018_final_public.csv")
df_orig.head
# Out:
#    PUBID  REGION  CENDIV  PBA  PUBCLIM    SQFT  SQFTC  WLCNS  RFCNS  RFCOOL  \
# 0      1       3       5    2        3  210000      8      1      4       2
# 1      2       4       9    2        4   28000      5      1      6       1
# 2      3       3       5    8        4    2100      2      1      4       2
# 3      4       3       7    5        5  240000      8      2      6       1
# 4      5       1       2    5        3  295000      8      3      6       2
#
#    ...  ZMFBTU  ZMFEXP  ZELCNS  ZELEXP  ZNGCNS  ZNGEXP  ZFKCNS  ZFKEXP  \
# 0  ...       0       0       0       0       9       9       1       1
# 1  ...       0       0       0       0       0       0       9       9
# 2  ...       0       0       0       0       9       9       9       9
# 3  ...       0       0       0       0       1       1       9       9
# 4  ...       0       0       0       0       0       0       9       9
#
#    ZDHBTU  ZDHEXP
# 0       0       0
# 1       9       9
# 2       9       9
# 3       9       9
# 4       9       9
#
# [5 rows x 1249 columns]

# %% [markdown]
# #### Create the working data file (df_wk), a subset of cbecs2018_final_public.csv.

# %%
# used column index id's to extract the working file data
df_wk = df_orig.iloc[:,[0,3,4,5,7,8,11,12,13,18,21,77,103,104,113,114,133,
    134,139,140,141,295,378,379,425,566,569,567,568,570,571,561,562]]
df_wk.head()
# Out:
#    PUBID  PBA  PUBCLIM    SQFT  WLCNS  RFCNS  BLDSHP  GLSSPC  NFLOOR  NELVTR  \
# 0      1    2        3  210000      1      4       6       3     994     8.0
# 1      2    2        4   28000      1      6      11       3       5     1.0
# 2      3    8        4    2100      1      4       2       3       1     NaN
# 3      4    5        5  240000      2      6       2       2       1     NaN
# 4      5    5        3  295000      3      6       1       1       1     NaN
#
#    ...  NGWATR  NGOTH       ELBTU      NGBTU      ELCNS     ELEXP    NGCNS  \
# 0  ...       2      2  18708970.0        NaN  5483285.0  775800.0      NaN
# 1  ...       1      2   1528667.0   201988.0   448027.0   77933.0   1946.0
# 2  ...       2      2     52387.0        NaN    15354.0    3472.0      NaN
# 3  ...       1      2   1974255.0  1211520.0   578621.0   41197.0  11672.0
# 4  ...       2      2   1290564.0  3386445.0   378243.0   33688.0  32625.0
#
#      NGEXP  HDD65  CDD65
# 0      NaN   4463   1759
# 1   4097.0   2424    189
# 2      NaN   3218   2403
# 3   9862.0   1045   3041
# 4  35297.0   5076   1316
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Add cold degree days (CDD) and hot degree days (HDD) low to high ranges and averages to df_wk.
# - The code cell below creates the df_clim dataframe.
# - The data is from "Climate Data for Building Design Standards".

# %%
data = {'PUBCLIM': [2, 3, 4],
        'CDD_LOW': [1800, 2700, 4500],
        'CDD_HI': [6300, 6300, 6300],
        'HDD_LOW': [5400, 3600, 1800],
        'HDD_HI': [7200, 5400, 3600],
        'CDD_AVG': [4050, 4500, 5400],
        'HDD_AVG': [6300, 4500, 2700]
        }

df_clim = pd.DataFrame(data)
print(df_clim)
# Out:
#    PUBCLIM  CDD_LOW  CDD_HI  HDD_LOW  HDD_HI  CDD_AVG  HDD_AVG
# 0        2     1800    6300     5400    7200     4050     6300
# 1        3     2700    6300     3600    5400     4500     4500
# 2        4     4500    6300     1800    3600     5400     2700

# %% [markdown]
# - This code cell joins the df_clim to df_wk using the common PUBCLIM column to align the rows based on the 2, 3, and 4 climate zones.

# %%
df_wk = pd.merge(df_wk, df_clim, on='PUBCLIM', how='left')
print(df_wk)
# Out:
#       PUBID  PBA  PUBCLIM    SQFT  WLCNS  RFCNS  BLDSHP  GLSSPC  NFLOOR  \
# 0         1    2        3  210000      1      4       6       3     994
# 1         2    2        4   28000      1      6      11       3       5
# 2         3    8        4    2100      1      4       2       3       1
# 3         4    5        5  240000      2      6       2       2       1
# 4         5    5        3  295000      3      6       1       1       1
# ...     ...  ...      ...     ...    ...    ...     ...     ...     ...
# 6431   6432   14        2  130000      1      1       2       3       3
# 6432   6433    1        4    1050      1      5       1       3       1
# 6433   6434    2        4  122000      2      6      11       5       5
# 6434   6435   23        4   15000      3      5       2       4       1
# 6435   6436   14        7  188000      1      6       4       2       7
#
#       NELVTR  ...    NGCNS    NGEXP  HDD65  CDD65  CDD_LOW  CDD_HI  HDD_LOW  \
# 0        8.0  ...      NaN      NaN   4463   1759   2700.0  6300.0   3600.0
# 1        1.0  ...   1946.0   4097.0   2424    189   4500.0  6300.0   1800.0
# 2        NaN  ...      NaN      NaN   3218   2403   4500.0  6300.0   1800.0
# 3        NaN  ...  11672.0   9862.0   1045   3041      NaN     NaN      NaN
# 4        NaN  ...  32625.0  35297.0   5076   1316   2700.0  6300.0   3600.0
# ...      ...  ...      ...      ...    ...    ...      ...     ...      ...
# 6431     1.0  ...  40083.0  24720.0   5645    612   1800.0  6300.0   5400.0
# 6432     NaN  ...      NaN      NaN   3210   2725   4500.0  6300.0   1800.0
# 6433     2.0  ...      NaN      NaN   2984   2117   4500.0  6300.0   1800.0
# 6434     NaN  ...   2268.0   2038.0   2414   4086   4500.0  6300.0   1800.0
# 6435     2.0  ...      NaN      NaN   5888    965      NaN     NaN      NaN
#
#       HDD_HI  CDD_AVG  HDD_AVG
# 0     5400.0   4500.0   4500.0
# 1     3600.0   5400.0   2700.0
# 2     3600.0   5400.0   2700.0
# 3        NaN      NaN      NaN
# 4     5400.0   4500.0   4500.0
# ...      ...      ...      ...
# 6431  7200.0   4050.0   6300.0
# 6432  3600.0   5400.0   2700.0
# 6433  3600.0   5400.0   2700.0
# 6434  3600.0   5400.0   2700.0
# 6435     NaN      NaN      NaN
#
# [6436 rows x 39 columns]

# %% [markdown]
# #### Filtered df_wk where the principle business activity (PBA) is 2 = office building, and the buildings are in climate zones PUBCLIM = 2 or 3 or 4.

# %%
df_wk_filtered = df_wk[(df_wk['PBA'] == 2) & (df_wk['PUBCLIM'].isin([2, 3, 4]))]
print(df_wk_filtered.shape)
print(df_wk_filtered)
# Out:
# (1018, 39)
#       PUBID  PBA  PUBCLIM    SQFT  WLCNS  RFCNS  BLDSHP  GLSSPC  NFLOOR  \
# 0         1    2        3  210000      1      4       6       3     994
# 1         2    2        4   28000      1      6      11       3       5
# 12       13    2        3   30500      1      6       2       5       3
# 18       19    2        4  184000      1      6       3       3       3
# 20       21    2        3  240000      6      5       2       6       4
# ...     ...  ...      ...     ...    ...    ...     ...     ...     ...
# 6420   6421    2        3  430000      1      7       2       4     995
# 6421   6422    2        2  385000      1      2       5       5       4
# 6427   6428    2        2  265000      2      8       1       5     995
# 6429   6430    2        4   54000      1      6       2       3       3
# 6433   6434    2        4  122000      2      6      11       5       5
#
#       NELVTR  ...     NGCNS    NGEXP  HDD65  CDD65  CDD_LOW  CDD_HI  HDD_LOW  \
# 0        8.0  ...       NaN      NaN   4463   1759   2700.0  6300.0   3600.0
# 1        1.0  ...    1946.0   4097.0   2424    189   4500.0  6300.0   1800.0
# 12       1.0  ...   14501.0   7140.0   4615   1184   2700.0  6300.0   3600.0
# 18       3.0  ...   57819.0  61657.0   3943   1680   4500.0  6300.0   1800.0
# 20       4.0  ...   72858.0  40230.0   5213   1708   2700.0  6300.0   3600.0
# ...      ...  ...       ...      ...    ...    ...      ...     ...      ...
# 6420     7.0  ...       NaN      NaN   4255    307   2700.0  6300.0   3600.0
# 6421     5.0  ...   85312.0  64654.0   6665   1008   1800.0  6300.0   5400.0
# 6427     6.0  ...  112456.0  40885.0   6681    730   1800.0  6300.0   5400.0
# 6429     2.0  ...       NaN      NaN   3227   1721   4500.0  6300.0   1800.0
# 6433     2.0  ...       NaN      NaN   2984   2117   4500.0  6300.0   1800.0
#
#       HDD_HI  CDD_AVG  HDD_AVG
# 0     5400.0   4500.0   4500.0
# 1     3600.0   5400.0   2700.0
# 12    5400.0   4500.0   4500.0
# 18    3600.0   5400.0   2700.0
# 20    5400.0   4500.0   4500.0
# ...      ...      ...      ...
# 6420  5400.0   4500.0   4500.0
# 6421  7200.0   4050.0   6300.0
# 6427  7200.0   4050.0   6300.0
# 6429  3600.0   5400.0   2700.0
# 6433  3600.0   5400.0   2700.0
#
# [1018 rows x 39 columns]

# %% [markdown]
# - The row index was reset so the new index is sequencial.

# %%
# resetting the df_wk row index
df_wk_filtered = df_wk_filtered.reset_index()
print(df_wk_filtered.shape)
print(df_wk_filtered)
# Out:
# (1018, 40)
#       index  PUBID  PBA  PUBCLIM    SQFT  WLCNS  RFCNS  BLDSHP  GLSSPC  \
# 0         0      1    2        3  210000      1      4       6       3
# 1         1      2    2        4   28000      1      6      11       3
# 2        12     13    2        3   30500      1      6       2       5
# 3        18     19    2        4  184000      1      6       3       3
# 4        20     21    2        3  240000      6      5       2       6
# ...     ...    ...  ...      ...     ...    ...    ...     ...     ...
# 1013   6420   6421    2        3  430000      1      7       2       4
# 1014   6421   6422    2        2  385000      1      2       5       5
# 1015   6427   6428    2        2  265000      2      8       1       5
# 1016   6429   6430    2        4   54000      1      6       2       3
# 1017   6433   6434    2        4  122000      2      6      11       5
#
#       NFLOOR  ...     NGCNS    NGEXP  HDD65  CDD65  CDD_LOW  CDD_HI  HDD_LOW  \
# 0        994  ...       NaN      NaN   4463   1759   2700.0  6300.0   3600.0
# 1          5  ...    1946.0   4097.0   2424    189   4500.0  6300.0   1800.0
# 2          3  ...   14501.0   7140.0   4615   1184   2700.0  6300.0   3600.0
# 3          3  ...   57819.0  61657.0   3943   1680   4500.0  6300.0   1800.0
# 4          4  ...   72858.0  40230.0   5213   1708   2700.0  6300.0   3600.0
# ...      ...  ...       ...      ...    ...    ...      ...     ...      ...
# 1013     995  ...       NaN      NaN   4255    307   2700.0  6300.0   3600.0
# 1014       4  ...   85312.0  64654.0   6665   1008   1800.0  6300.0   5400.0
# 1015     995  ...  112456.0  40885.0   6681    730   1800.0  6300.0   5400.0
# 1016       3  ...       NaN      NaN   3227   1721   4500.0  6300.0   1800.0
# 1017       5  ...       NaN      NaN   2984   2117   4500.0  6300.0   1800.0
#
#       HDD_HI  CDD_AVG  HDD_AVG
# 0     5400.0   4500.0   4500.0
# 1     3600.0   5400.0   2700.0
# 2     5400.0   4500.0   4500.0
# 3     3600.0   5400.0   2700.0
# 4     5400.0   4500.0   4500.0
# ...      ...      ...      ...
# 1013  5400.0   4500.0   4500.0
# 1014  7200.0   4050.0   6300.0
# 1015  7200.0   4050.0   6300.0
# 1016  3600.0   5400.0   2700.0
# 1017  3600.0   5400.0   2700.0
#
# [1018 rows x 40 columns]

# %% [markdown]
# #### Data summary.

# %%
def run_sumarize(df):
    print('The number of rows and columns is:')
    print(df.shape)
    print('\nListing of all columns and information about them is:')
    print(df.info())
    print('\nThe number of rows w/ null values in each column is:')
    print(df.isnull().sum())
    print('\nThe basic statistic and descriptive values for the selected columns are: ')
    print(df[['SQFT', 'ELCNS', 'NGCNS']].describe().round(2))
    
run_sumarize(df_wk_filtered)
# Out:
# The number of rows and columns is:
# (1018, 40)
#
# Listing of all columns and information about them is:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 40 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      1018 non-null   int64
#  1   PUBID      1018 non-null   int64
#  2   PBA        1018 non-null   int64
#  3   PUBCLIM    1018 non-null   int64
#  4   SQFT       1018 non-null   int64
#  5   WLCNS      1018 non-null   int64
#  6   RFCNS      1018 non-null   int64
#  7   BLDSHP     1018 non-null   int64
#  8   GLSSPC     1018 non-null   int64
#  9   NFLOOR     1018 non-null   int64
#  10  NELVTR     696 non-null    float64
#  11  YRCONC     1018 non-null   int64
#  12  WKHRSC     1018 non-null   int64
#  13  ELHT1      1018 non-null   int64
#  14  NGHT1      1018 non-null   int64
#  15  ELHT2      1018 non-null   int64
#  16  NGHT2      1018 non-null   int64
#  17  BOILER_EL  583 non-null    float64
#  18  HTPMPH_EL  583 non-null    float64
#  19  OTHTEQ_EL  583 non-null    float64
#  20  PKGHT_NG   573 non-null    float64
#  21  BOILER_NG  573 non-null    float64
#  22  ELCOOL     1018 non-null   int64
#  23  ELWATR     1018 non-null   int64
#  24  NGWATR     1018 non-null   int64
#  25  NGOTH      1018 non-null   int64
#  26  ELBTU      1018 non-null   float64
#  27  NGBTU      692 non-null    float64
#  28  ELCNS      1018 non-null   float64
#  29  ELEXP      1018 non-null   float64
#  30  NGCNS      692 non-null    float64
#  31  NGEXP      692 non-null    float64
#  32  HDD65      1018 non-null   int64
#  33  CDD65      1018 non-null   int64
#  34  CDD_LOW    1018 non-null   float64
#  35  CDD_HI     1018 non-null   float64
#  36  HDD_LOW    1018 non-null   float64
#  37  HDD_HI     1018 non-null   float64
#  38  CDD_AVG    1018 non-null   float64
#  39  HDD_AVG    1018 non-null   float64
# dtypes: float64(18), int64(22)
# memory usage: 318.3 KB
# None
#
# The number of rows w/ null values in each column is:
# index          0
# PUBID          0
# PBA            0
# PUBCLIM        0
# SQFT           0
# WLCNS          0
# RFCNS          0
# BLDSHP         0
# GLSSPC         0
# NFLOOR         0
# NELVTR       322
# YRCONC         0
# WKHRSC         0
# ELHT1          0
# NGHT1          0
# ELHT2          0
# NGHT2          0
# BOILER_EL    435
# HTPMPH_EL    435
# OTHTEQ_EL    435
# PKGHT_NG     445
# BOILER_NG    445
# ELCOOL         0
# ELWATR         0
# NGWATR         0
# NGOTH          0
# ELBTU          0
# NGBTU        326
# ELCNS          0
# ELEXP          0
# NGCNS        326
# NGEXP        326
# HDD65          0
# CDD65          0
# CDD_LOW        0
# CDD_HI         0
# HDD_LOW        0
# HDD_HI         0
# CDD_AVG        0
# HDD_AVG        0
# dtype: int64
#
# The basic statistic and descriptive values for the selected columns are:
#              SQFT        ELCNS      NGCNS
# count     1018.00      1018.00     692.00
# mean    175484.75   2600291.00   29085.64
# std     204035.41   3704654.05   48251.22
# min       1001.00      3342.00       1.00
# 25%      14500.00    147692.50    2434.75
# 50%     102000.00   1213733.50   11565.00
# 75%     250000.00   3577499.00   31915.75
# max    1000000.00  37158137.00  421080.00

# %%
def run_value_counts(df):
    print('The number of responses for each climate zone catagory is:')
    print(df['PUBCLIM'].value_counts().sort_values(ascending=False))
    print('\nThe number of responses for each building shape catagory is:')
    print(df['BLDSHP'].value_counts().sort_values(ascending=False))
    print('\nThe number of responses for each exterior glass percent catagory is:')
    print(df['GLSSPC'].value_counts().sort_values(ascending=False))
    print('\nThe number of responses for number of elevators is:')
    print(df['NELVTR'].value_counts().sort_values(ascending=False))
    print('\nThe number of responses for each construction year catagory is:')
    print(df['YRCONC'].value_counts().sort_values(ascending=False))
    print('\nThe number of responses for each weekly building hours open catagory is:')
    print(df['WKHRSC'].value_counts().sort_values(ascending=False))
    print('\nThe number of responses for main heating by electricity is:')
    print(df['ELHT1'].value_counts().sort_values(ascending=False))
    print('\nThe number of responses for main heating by natural gas is:')
    print(df['NGHT1'].value_counts().sort_values(ascending=False))
    print('\nThe number of responses for air conditioning by electricity is:')
    print(df['ELCOOL'].value_counts().sort_values(ascending=False))
    print('\nThe number of responses for water heating by electricity is:')
    print(df['ELWATR'].value_counts().sort_values(ascending=False))
    print('\nThe number of responses for water heating by electricity is:')
    print(df['NGWATR'].value_counts().sort_values(ascending=False))
    print('\nThe number of responses for number of floors catagory is:')
    print(df['NFLOOR'].value_counts().sort_values(ascending=False))
run_value_counts(df_wk_filtered)
# Out:
# The number of responses for each climate zone catagory is:
# PUBCLIM
# 3    410
# 4    326
# 2    282
# Name: count, dtype: int64
#
# The number of responses for each building shape catagory is:
# BLDSHP
# 2     588
# 1     141
# 11     71
# 9      64
# 3      47
# 4      35
# 6      31
# 5      19
# 8      13
# 7       6
# 10      3
# Name: count, dtype: int64
#
# The number of responses for each exterior glass percent catagory is:
# GLSSPC
# 3    327
# 4    247
# 2    181
# 5    145
# 6     69
# 1     49
# Name: count, dtype: int64
#
# The number of responses for number of elevators is:
# NELVTR
# 1.0      139
# 2.0      117
# 3.0       96
# 4.0       61
# 6.0       61
# 5.0       50
# 7.0       31
# 8.0       22
# 10.0      22
# 9.0       20
# 12.0      17
# 11.0      14
# 14.0      12
# 13.0       8
# 17.0       5
# 15.0       5
# 16.0       4
# 18.0       3
# 22.0       2
# 19.0       2
# 20.0       2
# 28.0       1
# 25.0       1
# 995.0      1
# Name: count, dtype: int64
#
# The number of responses for each construction year catagory is:
# YRCONC
# 6    235
# 8    167
# 2    156
# 7    151
# 5    130
# 4     91
# 3     45
# 9     43
# Name: count, dtype: int64
#
# The number of responses for each weekly building hours open catagory is:
# WKHRSC
# 4    374
# 3    264
# 5    160
# 7    113
# 2     69
# 6     38
# Name: count, dtype: int64
#
# The number of responses for main heating by electricity is:
# ELHT1
# 2    612
# 1    406
# Name: count, dtype: int64
#
# The number of responses for main heating by natural gas is:
# NGHT1
# 2    529
# 1    489
# Name: count, dtype: int64
#
# The number of responses for air conditioning by electricity is:
# ELCOOL
# 1    969
# 2     49
# Name: count, dtype: int64
#
# The number of responses for water heating by electricity is:
# ELWATR
# 1    603
# 2    415
# Name: count, dtype: int64
#
# The number of responses for water heating by electricity is:
# NGWATR
# 2    567
# 1    451
# Name: count, dtype: int64
#
# The number of responses for number of floors catagory is:
# NFLOOR
# 1      206
# 2      170
# 3      131
# 995    125
# 994    102
# 4       87
# 5       67
# 6       46
# 7       31
# 8       29
# 9       24
# Name: count, dtype: int64

# %% [markdown]
# #### Data clean up.

# %% [markdown]
# ##### The formula below calculates a fill-in value for the rows with missing data in HGCNS column.  See describe() output at the end of the run_sumarize function.
# - The mean of the existing values is much higher than the 50% percentile (median) value.
# - This means the distribution of the values is skewed higher than the median value.
# - I chose a value between the mean and median due to the mean being so much higher than the median value.

# %%
# fillna value for NGCNS missing values
mean = 29085
median = 11565
result = ((mean - median) / 2) + median
print(result)
# Out:
# 20325.0

# %% [markdown]
# - NGCNS (annual natural gas used) and NELVTR (number of elevators) fillna values to replace missing values.
# - The fillna value for the NELVTR missing data cells was the most used value.

# %%
# fillna value into the missing value cells
# a Pandas FutureWarning message will appear as output 
df_wk_filtered['NGCNS'].fillna(20325, inplace=True)
# Out:
# /var/folders/t_/5ddm1nld4m1fz6fjlbwhxmvc0000gp/T/ipykernel_23677/2817870500.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_wk_filtered['NGCNS'].fillna(20325, inplace=True)

# %% [markdown]
# - Verify the fillna values were successfully replaced.

# %%
# fillna value for NELVTR
# a Pandas FutureWarning message will appear as output 
df_wk_filtered['NELVTR'].fillna(1, inplace=True)
# Out:
# /var/folders/t_/5ddm1nld4m1fz6fjlbwhxmvc0000gp/T/ipykernel_23677/2122555226.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_wk_filtered['NELVTR'].fillna(1, inplace=True)

# %%
# verify missing values have been replaced.
print('The number of rows and columns is:')
print(df_wk_filtered.shape)
print('\nThe number of rows w/ null values in each column is:')
print(df_wk_filtered[['NGCNS','NELVTR']].isnull().sum())
# Out:
# The number of rows and columns is:
# (1018, 40)
#
# The number of rows w/ null values in each column is:
# NGCNS     0
# NELVTR    0
# dtype: int64

# %% [markdown]
# #### Created two calculated columns based on data from both data sources.

# %% [markdown]
# - The CDD65 nad HDD65 columns in the dataset are highly perturbed using a normal distribution resulting in an almost value in many cases not reflecting the true value of cold degree days or hot degree days found in the respective climate zones.
# - I wanted to see if these CDD65 and HDD65 values were in or out of correct climate zone values.

# %%
# function to create the new calculated CDD_RANGE column
def calc_cdd_range(row):
  """Calculates the CDD_range value for a each row.
  Args:
    row
  Returns:
    if CDD_LOW <= CDD65 <= CDD_HI then 'yes', else 'no'.
  """
  if row['CDD_LOW'] <= row['CDD65'] <= row['CDD_HI']:
    return 'yes'
  else:
    return 'no'

# function is applied to df_wk_filtered to create the new column
df_wk_filtered['CDD_RANGE'] = df_wk_filtered.apply(calc_cdd_range, axis=1)

# %%
# funtion to create the new calculated CDD_RANGE column
def calc_hdd_range(row):
  """Calculates the HDD_range value for a each row.
  Args:
    row
  Returns:
    if HDD_LOW <= HDD65 <= HDD_HI then 'yes', else 'no'.
  """
  if row['HDD_LOW'] <= row['HDD65'] <= row['HDD_HI']:
    return 'yes'
  else:
    return 'no'

# function is applied to df_wk_filtered to create the new column
df_wk_filtered['HDD_RANGE'] = df_wk_filtered.apply(calc_hdd_range, axis=1)

# %% [markdown]
# #### Verify that the calculated columns were populated

# %%
df_wk_filtered.shape
# Out:
# (1018, 42)

# %%
# set display option
pd.set_option('display.max_rows', 75)
column = df_wk_filtered['HDD_RANGE']
print(column)
# Out:
# 0       yes
# 1       yes
# 2       yes
# 3        no
# 4       yes
#        ...
# 1013    yes
# 1014    yes
# 1015    yes
# 1016    yes
# 1017    yes
# Name: HDD_RANGE, Length: 1018, dtype: object

# %% [markdown]
# #### Correlaton matrices
# - There is one matrix for electricity annual use (ELCHS) and inputs variables. And, another for natural gas annual use (NGCNS) and those associated inputs.
# - The correlation matrix for the all columns was difficult to interpret, and very large.
# - There was also a concern about interaction between the large number of variables.  As an example, the annual electricity use and the annual natural gas use showed a high correlation value which I can't explain

# %%
# had to use only numeric columns for the correlation analysis
# this script filtered out all non-numeric columns
df_wk_filtered_num = df_wk_filtered.select_dtypes(include=np.number)
# corr_matrix = df_wk_filtered_num.corr().round(2)
# print(corr_matrix)

# %% [markdown]
# #### Correlation matrix for annual electricity use (ELCNS) and input variables.

# %%
# created matrix and rounded to two decimal places
select_el = ['ELCNS', 'PUBCLIM', 'SQFT', 'WLCNS', 'RFCNS', 'BLDSHP', 'GLSSPC', 'NFLOOR', 'NELVTR', 'WKHRSC',
             'ELHT1', 'BOILER_EL', 'ELCOOL', 'ELWATR']
corr_matrix_el = df_wk_filtered_num[select_el].corr().round(2)
print(corr_matrix_el)
# Out:
#            ELCNS  PUBCLIM  SQFT  WLCNS  RFCNS  BLDSHP  GLSSPC  NFLOOR  NELVTR  \
# ELCNS       1.00     0.00  0.79   0.14   0.03    0.02    0.34    0.52    0.12
# PUBCLIM     0.00     1.00 -0.02   0.00  -0.07   -0.00    0.01   -0.03   -0.01
# SQFT        0.79    -0.02  1.00   0.16   0.03    0.02    0.41    0.61    0.14
# WLCNS       0.14     0.00  0.16   1.00   0.06   -0.03    0.33    0.17    0.02
# RFCNS       0.03    -0.07  0.03   0.06   1.00    0.02    0.06    0.01    0.03
# BLDSHP      0.02    -0.00  0.02  -0.03   0.02    1.00    0.05   -0.09   -0.03
# GLSSPC      0.34     0.01  0.41   0.33   0.06    0.05    1.00    0.35    0.06
# NFLOOR      0.52    -0.03  0.61   0.17   0.01   -0.09    0.35    1.00    0.15
# NELVTR      0.12    -0.01  0.14   0.02   0.03   -0.03    0.06    0.15    1.00
# WKHRSC      0.33    -0.02  0.27   0.01   0.03    0.02    0.19    0.21    0.05
# ELHT1      -0.07    -0.15 -0.03  -0.06  -0.01   -0.03   -0.11   -0.09   -0.04
# BOILER_EL  -0.01     0.03 -0.01  -0.03   0.00   -0.04   -0.10   -0.02    0.01
# ELCOOL      0.02    -0.07  0.08   0.01  -0.02   -0.02    0.01    0.01   -0.00
# ELWATR     -0.07    -0.07 -0.06  -0.08  -0.03    0.02   -0.12   -0.07    0.03
#
#            WKHRSC  ELHT1  BOILER_EL  ELCOOL  ELWATR
# ELCNS        0.33  -0.07      -0.01    0.02   -0.07
# PUBCLIM     -0.02  -0.15       0.03   -0.07   -0.07
# SQFT         0.27  -0.03      -0.01    0.08   -0.06
# WLCNS        0.01  -0.06      -0.03    0.01   -0.08
# RFCNS        0.03  -0.01       0.00   -0.02   -0.03
# BLDSHP       0.02  -0.03      -0.04   -0.02    0.02
# GLSSPC       0.19  -0.11      -0.10    0.01   -0.12
# NFLOOR       0.21  -0.09      -0.02    0.01   -0.07
# NELVTR       0.05  -0.04       0.01   -0.00    0.03
# WKHRSC       1.00  -0.01      -0.01    0.01    0.02
# ELHT1       -0.01   1.00       0.10    0.15    0.44
# BOILER_EL   -0.01   0.10       1.00    0.04    0.07
# ELCOOL       0.01   0.15       0.04    1.00    0.13
# ELWATR       0.02   0.44       0.07    0.13    1.00

# %% [markdown]
# #### Unstacked the ELCNS matrix for further analysis.

# %%
# adjusted the output display for maximum rows w/ no limit
# unstacked the matrix to filter out negative correlation values
pd.set_option('display.max_rows', None)
unstack_corr_el = corr_matrix_el.unstack()
positive_corr = unstack_corr_el[unstack_corr_el > 0]
print(positive_corr)
# Out:
# ELCNS      ELCNS        1.00
#            SQFT         0.79
#            WLCNS        0.14
#            RFCNS        0.03
#            BLDSHP       0.02
#            GLSSPC       0.34
#            NFLOOR       0.52
#            NELVTR       0.12
#            WKHRSC       0.33
#            ELCOOL       0.02
# PUBCLIM    PUBCLIM      1.00
#            GLSSPC       0.01
#            BOILER_EL    0.03
# SQFT       ELCNS        0.79
#            SQFT         1.00
#            WLCNS        0.16
#            RFCNS        0.03
#            BLDSHP       0.02
#            GLSSPC       0.41
#            NFLOOR       0.61
#            NELVTR       0.14
#            WKHRSC       0.27
#            ELCOOL       0.08
# WLCNS      ELCNS        0.14
#            SQFT         0.16
#            WLCNS        1.00
#            RFCNS        0.06
#            GLSSPC       0.33
#            NFLOOR       0.17
#            NELVTR       0.02
#            WKHRSC       0.01
#            ELCOOL       0.01
# RFCNS      ELCNS        0.03
#            SQFT         0.03
#            WLCNS        0.06
#            RFCNS        1.00
#            BLDSHP       0.02
#            GLSSPC       0.06
#            NFLOOR       0.01
#            NELVTR       0.03
#            WKHRSC       0.03
# BLDSHP     ELCNS        0.02
#            SQFT         0.02
#            RFCNS        0.02
#            BLDSHP       1.00
#            GLSSPC       0.05
#            WKHRSC       0.02
#            ELWATR       0.02
# GLSSPC     ELCNS        0.34
#            PUBCLIM      0.01
#            SQFT         0.41
#            WLCNS        0.33
#            RFCNS        0.06
#            BLDSHP       0.05
#            GLSSPC       1.00
#            NFLOOR       0.35
#            NELVTR       0.06
#            WKHRSC       0.19
#            ELCOOL       0.01
# NFLOOR     ELCNS        0.52
#            SQFT         0.61
#            WLCNS        0.17
#            RFCNS        0.01
#            GLSSPC       0.35
#            NFLOOR       1.00
#            NELVTR       0.15
#            WKHRSC       0.21
#            ELCOOL       0.01
# NELVTR     ELCNS        0.12
#            SQFT         0.14
#            WLCNS        0.02
#            RFCNS        0.03
#            GLSSPC       0.06
#            NFLOOR       0.15
#            NELVTR       1.00
#            WKHRSC       0.05
#            BOILER_EL    0.01
#            ELWATR       0.03
# WKHRSC     ELCNS        0.33
#            SQFT         0.27
#            WLCNS        0.01
#            RFCNS        0.03
#            BLDSHP       0.02
#            GLSSPC       0.19
#            NFLOOR       0.21
#            NELVTR       0.05
#            WKHRSC       1.00
#            ELCOOL       0.01
#            ELWATR       0.02
# ELHT1      ELHT1        1.00
#            BOILER_EL    0.10
#            ELCOOL       0.15
#            ELWATR       0.44
# BOILER_EL  PUBCLIM      0.03
#            NELVTR       0.01
#            ELHT1        0.10
#            BOILER_EL    1.00
#            ELCOOL       0.04
#            ELWATR       0.07
# ELCOOL     ELCNS        0.02
#            SQFT         0.08
#            WLCNS        0.01
#            GLSSPC       0.01
#            NFLOOR       0.01
#            WKHRSC       0.01
#            ELHT1        0.15
#            BOILER_EL    0.04
#            ELCOOL       1.00
#            ELWATR       0.13
# ELWATR     BLDSHP       0.02
#            NELVTR       0.03
#            WKHRSC       0.02
#            ELHT1        0.44
#            BOILER_EL    0.07
#            ELCOOL       0.13
#            ELWATR       1.00
# dtype: float64

# %% [markdown]
# #### Correlation matrix for annual natural gas use NGCNS and input variables.

# %%
select_ng = ['NGCNS', 'PUBCLIM', 'SQFT', 'WLCNS', 'RFCNS', 'BLDSHP', 'GLSSPC', 'NFLOOR', 
             'NELVTR', 'WKHRSC', 'NGHT1', 'BOILER_NG', 'NGWATR'] 
corr_matrix_ng = df_wk_filtered_num[select_ng].corr().round(2)
print(corr_matrix_ng)
# Out:
#            NGCNS  PUBCLIM  SQFT  WLCNS  RFCNS  BLDSHP  GLSSPC  NFLOOR  NELVTR  \
# NGCNS       1.00    -0.11  0.42   0.07   0.05    0.01    0.15    0.24    0.03
# PUBCLIM    -0.11     1.00 -0.02   0.00  -0.07   -0.00    0.01   -0.03   -0.01
# SQFT        0.42    -0.02  1.00   0.16   0.03    0.02    0.41    0.61    0.14
# WLCNS       0.07     0.00  0.16   1.00   0.06   -0.03    0.33    0.17    0.02
# RFCNS       0.05    -0.07  0.03   0.06   1.00    0.02    0.06    0.01    0.03
# BLDSHP      0.01    -0.00  0.02  -0.03   0.02    1.00    0.05   -0.09   -0.03
# GLSSPC      0.15     0.01  0.41   0.33   0.06    0.05    1.00    0.35    0.06
# NFLOOR      0.24    -0.03  0.61   0.17   0.01   -0.09    0.35    1.00    0.15
# NELVTR      0.03    -0.01  0.14   0.02   0.03   -0.03    0.06    0.15    1.00
# WKHRSC      0.21    -0.02  0.27   0.01   0.03    0.02    0.19    0.21    0.05
# NGHT1      -0.17     0.10  0.14   0.08   0.01    0.00    0.08    0.18    0.05
# BOILER_NG  -0.36     0.03 -0.42  -0.12  -0.03   -0.12   -0.36   -0.33   -0.43
# NGWATR     -0.15     0.06  0.03   0.05   0.01   -0.08    0.01    0.10   -0.03
#
#            WKHRSC  NGHT1  BOILER_NG  NGWATR
# NGCNS        0.21  -0.17      -0.36   -0.15
# PUBCLIM     -0.02   0.10       0.03    0.06
# SQFT         0.27   0.14      -0.42    0.03
# WLCNS        0.01   0.08      -0.12    0.05
# RFCNS        0.03   0.01      -0.03    0.01
# BLDSHP       0.02   0.00      -0.12   -0.08
# GLSSPC       0.19   0.08      -0.36    0.01
# NFLOOR       0.21   0.18      -0.33    0.10
# NELVTR       0.05   0.05      -0.43   -0.03
# WKHRSC       1.00   0.03      -0.24    0.02
# NGHT1        0.03   1.00       0.13    0.56
# BOILER_NG   -0.24   0.13       1.00    0.18
# NGWATR       0.02   0.56       0.18    1.00

# %% [markdown]
# #### Unstacked the NGCNS matrix for further analysis.

# %%
pd.set_option('display.max_rows', None)
unstack_corr_ng = corr_matrix_ng.unstack()
positive_corr = unstack_corr_ng[unstack_corr_ng > 0]
print(positive_corr)
# Out:
# NGCNS      NGCNS        1.00
#            SQFT         0.42
#            WLCNS        0.07
#            RFCNS        0.05
#            BLDSHP       0.01
#            GLSSPC       0.15
#            NFLOOR       0.24
#            NELVTR       0.03
#            WKHRSC       0.21
# PUBCLIM    PUBCLIM      1.00
#            GLSSPC       0.01
#            NGHT1        0.10
#            BOILER_NG    0.03
#            NGWATR       0.06
# SQFT       NGCNS        0.42
#            SQFT         1.00
#            WLCNS        0.16
#            RFCNS        0.03
#            BLDSHP       0.02
#            GLSSPC       0.41
#            NFLOOR       0.61
#            NELVTR       0.14
#            WKHRSC       0.27
#            NGHT1        0.14
#            NGWATR       0.03
# WLCNS      NGCNS        0.07
#            SQFT         0.16
#            WLCNS        1.00
#            RFCNS        0.06
#            GLSSPC       0.33
#            NFLOOR       0.17
#            NELVTR       0.02
#            WKHRSC       0.01
#            NGHT1        0.08
#            NGWATR       0.05
# RFCNS      NGCNS        0.05
#            SQFT         0.03
#            WLCNS        0.06
#            RFCNS        1.00
#            BLDSHP       0.02
#            GLSSPC       0.06
#            NFLOOR       0.01
#            NELVTR       0.03
#            WKHRSC       0.03
#            NGHT1        0.01
#            NGWATR       0.01
# BLDSHP     NGCNS        0.01
#            SQFT         0.02
#            RFCNS        0.02
#            BLDSHP       1.00
#            GLSSPC       0.05
#            WKHRSC       0.02
# GLSSPC     NGCNS        0.15
#            PUBCLIM      0.01
#            SQFT         0.41
#            WLCNS        0.33
#            RFCNS        0.06
#            BLDSHP       0.05
#            GLSSPC       1.00
#            NFLOOR       0.35
#            NELVTR       0.06
#            WKHRSC       0.19
#            NGHT1        0.08
#            NGWATR       0.01
# NFLOOR     NGCNS        0.24
#            SQFT         0.61
#            WLCNS        0.17
#            RFCNS        0.01
#            GLSSPC       0.35
#            NFLOOR       1.00
#            NELVTR       0.15
#            WKHRSC       0.21
#            NGHT1        0.18
#            NGWATR       0.10
# NELVTR     NGCNS        0.03
#            SQFT         0.14
#            WLCNS        0.02
#            RFCNS        0.03
#            GLSSPC       0.06
#            NFLOOR       0.15
#            NELVTR       1.00
#            WKHRSC       0.05
#            NGHT1        0.05
# WKHRSC     NGCNS        0.21
#            SQFT         0.27
#            WLCNS        0.01
#            RFCNS        0.03
#            BLDSHP       0.02
#            GLSSPC       0.19
#            NFLOOR       0.21
#            NELVTR       0.05
#            WKHRSC       1.00
#            NGHT1        0.03
#            NGWATR       0.02
# NGHT1      PUBCLIM      0.10
#            SQFT         0.14
#            WLCNS        0.08
#            RFCNS        0.01
#            GLSSPC       0.08
#            NFLOOR       0.18
#            NELVTR       0.05
#            WKHRSC       0.03
#            NGHT1        1.00
#            BOILER_NG    0.13
#            NGWATR       0.56
# BOILER_NG  PUBCLIM      0.03
#            NGHT1        0.13
#            BOILER_NG    1.00
#            NGWATR       0.18
# NGWATR     PUBCLIM      0.06
#            SQFT         0.03
#            WLCNS        0.05
#            RFCNS        0.01
#            GLSSPC       0.01
#            NFLOOR       0.10
#            WKHRSC       0.02
#            NGHT1        0.56
#            BOILER_NG    0.18
#            NGWATR       1.00
# dtype: float64

# %% [markdown]
# #### Scatter plots of ELCNS and NGCNS, and select input variables.

# %%
# set default marker size
plt.rcParams['lines.markersize'] = 4

# assign x and y values
x = df_wk_filtered_num['SQFT']
y = df_wk_filtered_num['NGCNS']

# adjust dimensions of plot
plt.figure(figsize=(8, 6)) 
# Create scatter plot
plt.scatter(x, y)

# calculate line of best fit
m, b = np.polyfit(x, y, 1)

# plot best fit line
plt.plot(x, m*x + b, color='red')
plt.xlabel("X-axis Label", labelpad=20)

# add labels and title
plt.xlabel("'SQFT', square feet in 200,000 square foot increments")
plt.ylabel("'NGCNS', natural gas used annually in 100,000 ccf units")
plt.title('Fig 1, Scatter Plot of building square feet and natural gas used annually\nCorrelation value = .42')

# Display plot
plt.show()

# %%
# set default marker size
# plt.rcParams['lines.markersize'] = 4

# assign x and y values
x = df_wk_filtered_num['SQFT']
y = df_wk_filtered_num['ELCNS']

# adjust dimensions of plot
plt.figure(figsize=(8, 6)) 

# create scatter plot
plt.scatter(x, y)

# calculate line of best fit
m, b = np.polyfit(x, y, 1)

# plot best fit line
plt.plot(x, m*x + b, color='red')
plt.xlabel("X-axis Label", labelpad=20)

# add labels and title
plt.xlabel("'SQFT', building square feet in 200,000 square foot increments")
plt.ylabel("'ELCNS', electricity used annually in 50,000 kWh units")
plt.title('Fig 2, Scatter Plot of the building square footage and electricity used annually\nCorrelation value = .79 ')

# display plot
plt.show()

# %% [markdown]
# #### The two following scatter plots are examples of plotting catagorical data.
# - The data for the two input variable, GLSSPC and WKHRSC are in ranges of percentages or hours open w/ a numeric value identifying the selected range.
# - The correlation values are reasonable, but the data does not render as expected in a scatter plot.

# %%
# set default marker size
# plt.rcParams['lines.markersize'] = 4

# assign x and y values
x = df_wk_filtered_num['GLSSPC']
y = df_wk_filtered_num['ELCNS']

# adjust dimensions of plot
plt.figure(figsize=(8, 6)) 
# create scatter plot
plt.scatter(x, y)

# calculate line of best fit
m, b = np.polyfit(x, y, 1)

# plot best fit line
plt.plot(x, m*x + b, color='red')
plt.xlabel("X-axis Label", labelpad=20)

# add labels and title
plt.xlabel("'GLSSPC', ouside building glass")
plt.ylabel("'ELCNS', electricity used annually in 50,000 kWh units")
plt.title('Fig 3, Scatter Plot of the outside glass percent and electricity used annually\nCorrelation value = .34 ')

# display plot
plt.show()

# %%
# set default marker size
# plt.rcParams['lines.markersize'] = 4

# extract x and y values
x = df_wk_filtered_num['WKHRSC']
y = df_wk_filtered_num['ELCNS']

# adjust dimensions of plot
plt.figure(figsize=(8, 6)) 

# create scatter plot
plt.scatter(x, y)

# calculate line of best fit
m, b = np.polyfit(x, y, 1)

# plot best fit line
plt.plot(x, m*x + b, color='red')
plt.xlabel("X-axis Label", labelpad=20)

# add labels and title
plt.xlabel("'WKHRSC', number of hours open")
plt.ylabel("'ELCNS', electricity used annually in 50,000 kWh units")
plt.title('Fig 4, Scatter Plot of number of hours open weekly and electricity used annually\nCorrelation value = .33 ')

# display plot
plt.show()
